# %%
import sys, os
import importlib.metadata

# Ajusta si tu carpeta local no se llama exactamente bullet3-3.25
sys.path.append(os.path.abspath("bullet3-3.25"))

import pybullet as p
import pybullet_data
import gymnasium as gym
import numpy as np
import torch

print("✅ PyBullet", importlib.metadata.version("pybullet"))
print("✅ Gymnasium", gym.__version__)
print("✅ Torch", torch.__version__)
# Out:
# ✅ PyBullet 3.2.7
# ✅ Gymnasium 1.1.1
# ✅ Torch 2.5.1+cu121

# %%
from gymnasium import spaces
import numpy as np
import pybullet as p
import pybullet_data

class RobotCupEnv(gym.Env):
    """Brazo Panda que voltea un vaso cilíndrico, con reward rebalanceado."""
    metadata = {"render_modes": ["human", "direct"], "render_fps": 240}

    def __init__(self, render_mode="direct"):
        super().__init__()
        self.render_mode = render_mode
        self.client = p.connect(p.GUI if render_mode=="human" else p.DIRECT)

        # Datos de PyBullet
        p.setAdditionalSearchPath(pybullet_data.getDataPath())
        self.time_step = 1/240
        p.setTimeStep(self.time_step, physicsClientId=self.client)
        p.setGravity(0,0,-9.8, physicsClientId=self.client)

        # Espacio de acciones (7 ángulos)
        self.action_space = spaces.Box(
            low  = np.array([-2.9]*7, dtype=np.float32),
            high = np.array([ 2.9]*7, dtype=np.float32)
        )
        # Observación: 7 ángulos + (x,y,z) del vaso
        low  = np.array([-3.2]*7 + [-1.0, -1.0, 0.0], dtype=np.float32)
        high = np.array([ 3.2]*7 + [ 1.0,  1.0, 1.0], dtype=np.float32)
        self.observation_space = spaces.Box(low, high, dtype=np.float32)

        self.max_steps    = 240 * 5
        self.step_counter = 0

    def reset(self, *, seed=None, options=None):
        # Reiniciar simulación
        p.resetSimulation(physicsClientId=self.client)
        p.setGravity(0,0,-9.8, physicsClientId=self.client)
        p.setTimeStep(self.time_step, physicsClientId=self.client)
        p.loadURDF("plane.urdf", physicsClientId=self.client)

        # Cargar robot
        self.robot_id = p.loadURDF(
            "franka_panda/panda.urdf",
            basePosition=[0,0,0],
            useFixedBase=True,
            physicsClientId=self.client
        )
        # Perturbar postura inicial ±5°
        for j in range(7):
            delta = self.np_random.uniform(-0.087, 0.087)
            p.resetJointState(self.robot_id, j, delta, physicsClientId=self.client)

        # Crear vaso en X∈[-0.3,0.3], Y∈[-0.1,0.1]
        col = p.createCollisionShape(p.GEOM_CYLINDER, radius=0.03, height=0.1,
                                     physicsClientId=self.client)
        vis = p.createVisualShape(p.GEOM_CYLINDER, radius=0.03, length=0.1,
                                  rgbaColor=[1,1,1,1],
                                  physicsClientId=self.client)
        x = self.np_random.uniform(-0.3, 0.3)
        y = self.np_random.uniform(-0.1, 0.1)
        self.cup_id = p.createMultiBody(
            baseMass=0.1,
            baseCollisionShapeIndex=col,
            baseVisualShapeIndex=vis,
            basePosition=[x, y, 0.05],
            physicsClientId=self.client
        )

        self.step_counter = 0
        return self._get_obs(), {}

    def step(self, action):
        # Aplicar acción de posición
        for i, tgt in enumerate(action):
            p.setJointMotorControl2(
                self.robot_id, jointIndex=i,
                controlMode=p.POSITION_CONTROL,
                targetPosition=tgt,
                physicsClientId=self.client
            )
        p.stepSimulation(physicsClientId=self.client)
        self.step_counter += 1

        # Calcular tilt actual
        _, quat = p.getBasePositionAndOrientation(self.cup_id,
                                                  physicsClientId=self.client)
        roll, pitch, _ = p.getEulerFromQuaternion(quat)
        tilt = max(abs(roll), abs(pitch))

        obs    = self._get_obs()
        reward = self._compute_reward(tilt)
        done   = self.step_counter >= self.max_steps
        # Termina tan pronto alcanza 0.8 rad (~45°)
        terminated = done or (tilt >= 0.8)

        return obs, reward, terminated, False, {}

    def _get_obs(self):
        # Ángulos de juntas
        js = p.getJointStates(self.robot_id, list(range(7)),
                              physicsClientId=self.client)
        angles = [s[0] for s in js]
        # Posición del vaso
        pos, _ = p.getBasePositionAndOrientation(self.cup_id,
                                                  physicsClientId=self.client)
        return np.array(angles + list(pos), dtype=np.float32)

    def _compute_reward(self, tilt: float) -> float:
        # tilt ∈ [0, π/2]
        r_tilt = np.clip(tilt / (np.pi/2), 0, 1)
        # bonus extra si pasa 45° (0.785 rad)
        bonus = 0.5 if tilt > 0.785 else 0.0
        # penalización suave
        penalty = 0.001
        return float(r_tilt + bonus - penalty)

    def render(self):
        pass

    def close(self):
        p.disconnect(physicsClientId=self.client)

# %%
env = RobotCupEnv(render_mode="direct")
obs, _ = env.reset()
for _ in range(200):
    a = env.action_space.sample()
    obs, r, done, trunc, _ = env.step(a)
    if done or trunc:
        break
env.close()
print("✅ Test direct completado | Reward:", r)
# Out:
# ✅ Test direct completado | Reward: -0.0008931550809759968

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecMonitor
from stable_baselines3.common.callbacks import EvalCallback

# — training env —
venv = DummyVecEnv([lambda: RobotCupEnv(render_mode="direct") for _ in range(4)])
venv = VecMonitor(venv)

# — eval env del mismo tipo —
eval_venv = DummyVecEnv([lambda: RobotCupEnv(render_mode="direct")])
eval_venv = VecMonitor(eval_venv)

# — callback de evaluación —
eval_cb = EvalCallback(
    eval_venv,
    best_model_save_path="./logs/",
    log_path="./logs/",
    eval_freq=20_000,
    n_eval_episodes=5,
    deterministic=True,
    render=False,
)

model = PPO(
    "MlpPolicy",
    venv,
    verbose=1,
    device="cpu",
    n_steps=256,
    learning_rate=1e-4,
    ent_coef=0.05,
    batch_size=64,
)

model.learn(total_timesteps=500_000, callback=eval_cb)
model.save("ppo_robot_cup_no_norm")
# Out:
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 537  |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 1024 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 498          |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0078258095 |
# |    clip_fraction        | 0.0304       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.94        |
# |    explained_variance   | -0.81        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.521       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 1            |
# |    value_loss           | 0.00621      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 425         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.008344868 |
# |    clip_fraction        | 0.0595      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.96       |
# |    explained_variance   | -1.33       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.541      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0141     |
# |    std                  | 1.01        |
# |    value_loss           | 0.000365    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 392         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009275767 |
# |    clip_fraction        | 0.0736      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.97       |
# |    explained_variance   | -0.00016    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.517      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 1.01        |
# |    value_loss           | 6.25e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.2e+03     |
# |    ep_rew_mean          | -0.806      |
# | time/                   |             |
# |    fps                  | 354         |
# |    iterations           | 5           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.005027095 |
# |    clip_fraction        | 0.0257      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.99       |
# |    explained_variance   | 0.602       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.487      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00634    |
# |    std                  | 1.01        |
# |    value_loss           | 3.1e-05     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.2e+03     |
# |    ep_rew_mean          | -0.806      |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 6           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.006096106 |
# |    clip_fraction        | 0.0221      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10         |
# |    explained_variance   | 0.0195      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.456      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00528    |
# |    std                  | 1.01        |
# |    value_loss           | 0.177       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.2e+03     |
# |    ep_rew_mean          | -0.806      |
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 7           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.011326869 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10         |
# |    explained_variance   | 0.168       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.52       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0191     |
# |    std                  | 1.02        |
# |    value_loss           | 0.00797     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.2e+03     |
# |    ep_rew_mean          | -0.806      |
# | time/                   |             |
# |    fps                  | 363         |
# |    iterations           | 8           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011487853 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.1       |
# |    explained_variance   | 0.881       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.543      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0166     |
# |    std                  | 1.02        |
# |    value_loss           | 0.000876    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.2e+03      |
# |    ep_rew_mean          | -0.806       |
# | time/                   |              |
# |    fps                  | 357          |
# |    iterations           | 9            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 0.0071472153 |
# |    clip_fraction        | 0.0757       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.1        |
# |    explained_variance   | 0.926        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.543       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0112      |
# |    std                  | 1.02         |
# |    value_loss           | 0.000505     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.2e+03     |
# |    ep_rew_mean          | 0.415       |
# | time/                   |             |
# |    fps                  | 347         |
# |    iterations           | 10          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.006907102 |
# |    clip_fraction        | 0.0433      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.1       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.509      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00709    |
# |    std                  | 1.03        |
# |    value_loss           | 0.000349    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.2e+03     |
# |    ep_rew_mean          | 0.415       |
# | time/                   |             |
# |    fps                  | 353         |
# |    iterations           | 11          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.005036493 |
# |    clip_fraction        | 0.0218      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.1       |
# |    explained_variance   | 0.645       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.497      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00489    |
# |    std                  | 1.03        |
# |    value_loss           | 0.000956    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.2e+03     |
# |    ep_rew_mean          | 0.415       |
# | time/                   |             |
# |    fps                  | 349         |
# |    iterations           | 12          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007328674 |
# |    clip_fraction        | 0.0618      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.2       |
# |    explained_variance   | 0.777       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.518      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0122     |
# |    std                  | 1.03        |
# |    value_loss           | 0.000126    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.2e+03    |
# |    ep_rew_mean          | 0.415      |
# | time/                   |            |
# |    fps                  | 348        |
# |    iterations           | 13         |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 13312      |
# | train/                  |            |
# |    approx_kl            | 0.00943329 |
# |    clip_fraction        | 0.0813     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.2      |
# |    explained_variance   | 0.878      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.529     |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0142    |
# |    std                  | 1.04       |
# |    value_loss           | 6.93e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.2e+03     |
# |    ep_rew_mean          | 0.415       |
# | time/                   |             |
# |    fps                  | 353         |
# |    iterations           | 14          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.007924499 |
# |    clip_fraction        | 0.0651      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.2       |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.525      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 1.04        |
# |    value_loss           | 5.17e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.11e+03    |
# |    ep_rew_mean          | 0.293       |
# | time/                   |             |
# |    fps                  | 349         |
# |    iterations           | 15          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.010350114 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.2       |
# |    explained_variance   | 0.902       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.536      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 1.04        |
# |    value_loss           | 3.93e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.11e+03    |
# |    ep_rew_mean          | 0.293       |
# | time/                   |             |
# |    fps                  | 348         |
# |    iterations           | 16          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007595923 |
# |    clip_fraction        | 0.0626      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.2       |
# |    explained_variance   | -0.0269     |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.467      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0062     |
# |    std                  | 1.05        |
# |    value_loss           | 0.318       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.11e+03    |
# |    ep_rew_mean          | 0.293       |
# | time/                   |             |
# |    fps                  | 351         |
# |    iterations           | 17          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.014932495 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.3       |
# |    explained_variance   | -0.861      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.546      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0215     |
# |    std                  | 1.05        |
# |    value_loss           | 0.0117      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.11e+03   |
# |    ep_rew_mean          | 0.293      |
# | time/                   |            |
# |    fps                  | 352        |
# |    iterations           | 18         |
# |    time_elapsed         | 52         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01073956 |
# |    clip_fraction        | 0.0944     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.3      |
# |    explained_variance   | -0.119     |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.547     |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0159    |
# |    std                  | 1.05       |
# |    value_loss           | 0.0029     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.07e+03    |
# |    ep_rew_mean          | 1.08        |
# | time/                   |             |
# |    fps                  | 348         |
# |    iterations           | 19          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.008989821 |
# |    clip_fraction        | 0.095       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.3       |
# |    explained_variance   | -1.08       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.535      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0169     |
# |    std                  | 1.06        |
# |    value_loss           | 0.00179     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.07e+03    |
# |    ep_rew_mean          | 1.08        |
# | time/                   |             |
# |    fps                  | 355         |
# |    iterations           | 20          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.006559661 |
# |    clip_fraction        | 0.0221      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.3       |
# |    explained_variance   | 0.0412      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.366      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00371    |
# |    std                  | 1.06        |
# |    value_loss           | 0.242       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.07e+03    |
# |    ep_rew_mean          | 1.08        |
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 21          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.008740426 |
# |    clip_fraction        | 0.0735      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.3       |
# |    explained_variance   | -0.706      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.487      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 1.06        |
# |    value_loss           | 0.0206      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.07e+03    |
# |    ep_rew_mean          | 1.08        |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 22          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.007862765 |
# |    clip_fraction        | 0.0675      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.3       |
# |    explained_variance   | -1.35       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.52       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0122     |
# |    std                  | 1.06        |
# |    value_loss           | 0.00377     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.07e+03    |
# |    ep_rew_mean          | 1.08        |
# | time/                   |             |
# |    fps                  | 373         |
# |    iterations           | 23          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.010838496 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.4       |
# |    explained_variance   | -1.69       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.541      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0162     |
# |    std                  | 1.07        |
# |    value_loss           | 0.00191     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.05e+03     |
# |    ep_rew_mean          | 1.56         |
# | time/                   |              |
# |    fps                  | 369          |
# |    iterations           | 24           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0061901333 |
# |    clip_fraction        | 0.0535       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.4        |
# |    explained_variance   | -1.07        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.544       |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00957     |
# |    std                  | 1.07         |
# |    value_loss           | 0.00107      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.05e+03     |
# |    ep_rew_mean          | 1.56         |
# | time/                   |              |
# |    fps                  | 375          |
# |    iterations           | 25           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 0.0064083664 |
# |    clip_fraction        | 0.0509       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.4        |
# |    explained_variance   | 0.00895      |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.36        |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00905     |
# |    std                  | 1.07         |
# |    value_loss           | 0.35         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.05e+03    |
# |    ep_rew_mean          | 1.56        |
# | time/                   |             |
# |    fps                  | 380         |
# |    iterations           | 26          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008774174 |
# |    clip_fraction        | 0.0725      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.4       |
# |    explained_variance   | -0.656      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.516      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0108     |
# |    std                  | 1.07        |
# |    value_loss           | 0.00846     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.05e+03    |
# |    ep_rew_mean          | 1.56        |
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 27          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.008184379 |
# |    clip_fraction        | 0.0682      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.4       |
# |    explained_variance   | 0.0904      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.557      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 1.07        |
# |    value_loss           | 0.00299     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.05e+03    |
# |    ep_rew_mean          | 1.56        |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 28          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.007076849 |
# |    clip_fraction        | 0.0695      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.4       |
# |    explained_variance   | 0.405       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.538      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 1.08        |
# |    value_loss           | 0.00195     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 997         |
# |    ep_rew_mean          | 1.75        |
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 29          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.008578384 |
# |    clip_fraction        | 0.0763      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.5       |
# |    explained_variance   | 0.674       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.57       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 1.08        |
# |    value_loss           | 0.0012      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 997          |
# |    ep_rew_mean          | 1.75         |
# | time/                   |              |
# |    fps                  | 385          |
# |    iterations           | 30           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0069008637 |
# |    clip_fraction        | 0.0401       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.5        |
# |    explained_variance   | -0.084       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.531       |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00686     |
# |    std                  | 1.09         |
# |    value_loss           | 0.256        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 997         |
# |    ep_rew_mean          | 1.75        |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 31          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.009471711 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.5       |
# |    explained_variance   | -0.888      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.556      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0187     |
# |    std                  | 1.09        |
# |    value_loss           | 0.00257     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 997          |
# |    ep_rew_mean          | 1.75         |
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 32           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0074619222 |
# |    clip_fraction        | 0.0673       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.5        |
# |    explained_variance   | -2.51        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.556       |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00966     |
# |    std                  | 1.09         |
# |    value_loss           | 0.00111      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 1.47        |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 33          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.008292213 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.6       |
# |    explained_variance   | -1.44       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.52       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0154     |
# |    std                  | 1.1         |
# |    value_loss           | 0.000702    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.02e+03     |
# |    ep_rew_mean          | 1.47         |
# | time/                   |              |
# |    fps                  | 391          |
# |    iterations           | 34           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0072727036 |
# |    clip_fraction        | 0.0381       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.6        |
# |    explained_variance   | 0.0177       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.532       |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00677     |
# |    std                  | 1.1          |
# |    value_loss           | 0.0148       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.02e+03     |
# |    ep_rew_mean          | 1.47         |
# | time/                   |              |
# |    fps                  | 393          |
# |    iterations           | 35           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 35840        |
# | train/                  |              |
# |    approx_kl            | 0.0066671097 |
# |    clip_fraction        | 0.0308       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.6        |
# |    explained_variance   | 0.0223       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.389       |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0055      |
# |    std                  | 1.11         |
# |    value_loss           | 0.382        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 1.47        |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 36          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.011068738 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.6       |
# |    explained_variance   | -0.287      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.55       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.016      |
# |    std                  | 1.11        |
# |    value_loss           | 0.0102      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 1.47        |
# | time/                   |             |
# |    fps                  | 400         |
# |    iterations           | 37          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.011421766 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.7       |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.527      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0137     |
# |    std                  | 1.11        |
# |    value_loss           | 0.00122     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 990         |
# |    ep_rew_mean          | 2.21        |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 38          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.005468937 |
# |    clip_fraction        | 0.0304      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.7       |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.538      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00593    |
# |    std                  | 1.12        |
# |    value_loss           | 0.000992    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 990          |
# |    ep_rew_mean          | 2.21         |
# | time/                   |              |
# |    fps                  | 397          |
# |    iterations           | 39           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 39936        |
# | train/                  |              |
# |    approx_kl            | 0.0055409046 |
# |    clip_fraction        | 0.0212       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.7        |
# |    explained_variance   | -0.14        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.403       |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.0049      |
# |    std                  | 1.12         |
# |    value_loss           | 0.571        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 990         |
# |    ep_rew_mean          | 2.21        |
# | time/                   |             |
# |    fps                  | 401         |
# |    iterations           | 40          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010701606 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.8       |
# |    explained_variance   | 0.512       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.579      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.019      |
# |    std                  | 1.13        |
# |    value_loss           | 0.00742     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 990         |
# |    ep_rew_mean          | 2.21        |
# | time/                   |             |
# |    fps                  | 406         |
# |    iterations           | 41          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.009799529 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.8       |
# |    explained_variance   | 0.822       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.531      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 1.13        |
# |    value_loss           | 0.00225     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 990          |
# |    ep_rew_mean          | 2.21         |
# | time/                   |              |
# |    fps                  | 405          |
# |    iterations           | 42           |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0099826865 |
# |    clip_fraction        | 0.0998       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.8        |
# |    explained_variance   | 0.902        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.542       |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.0132      |
# |    std                  | 1.14         |
# |    value_loss           | 0.00115      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | 1.9         |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 43          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.009270014 |
# |    clip_fraction        | 0.0847      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.556      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 1.15        |
# |    value_loss           | 0.000918    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.01e+03     |
# |    ep_rew_mean          | 1.9          |
# | time/                   |              |
# |    fps                  | 397          |
# |    iterations           | 44           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0071988953 |
# |    clip_fraction        | 0.0448       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.9        |
# |    explained_variance   | 0.00755      |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.37        |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00667     |
# |    std                  | 1.15         |
# |    value_loss           | 0.471        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.01e+03   |
# |    ep_rew_mean          | 1.9        |
# | time/                   |            |
# |    fps                  | 397        |
# |    iterations           | 45         |
# |    time_elapsed         | 115        |
# |    total_timesteps      | 46080      |
# | train/                  |            |
# |    approx_kl            | 0.01317309 |
# |    clip_fraction        | 0.163      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.9      |
# |    explained_variance   | 0.161      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.567     |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0249    |
# |    std                  | 1.15       |
# |    value_loss           | 0.0126     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.01e+03    |
# |    ep_rew_mean          | 1.9         |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 46          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009828979 |
# |    clip_fraction        | 0.0924      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | 0.668       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.546      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 1.16        |
# |    value_loss           | 0.00348     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.02e+03     |
# |    ep_rew_mean          | 2.33         |
# | time/                   |              |
# |    fps                  | 391          |
# |    iterations           | 47           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 48128        |
# | train/                  |              |
# |    approx_kl            | 0.0068226606 |
# |    clip_fraction        | 0.0573       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11          |
# |    explained_variance   | 0.871        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.548       |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00908     |
# |    std                  | 1.16         |
# |    value_loss           | 0.00176      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | 2.19        |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 48          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.006712539 |
# |    clip_fraction        | 0.0416      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | 0.47        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.554      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00554    |
# |    std                  | 1.16        |
# |    value_loss           | 0.00529     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.03e+03     |
# |    ep_rew_mean          | 2.19         |
# | time/                   |              |
# |    fps                  | 386          |
# |    iterations           | 49           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 50176        |
# | train/                  |              |
# |    approx_kl            | 0.0059797894 |
# |    clip_fraction        | 0.0243       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11          |
# |    explained_variance   | 0.157        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.559       |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00482     |
# |    std                  | 1.17         |
# |    value_loss           | 0.0112       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | 2.19        |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 50          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008517424 |
# |    clip_fraction        | 0.0693      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | 0.738       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.561      |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 1.17        |
# |    value_loss           | 0.000904    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | 2.19        |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 51          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 52224       |
# | train/                  |             |
# |    approx_kl            | 0.009642624 |
# |    clip_fraction        | 0.0895      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | 0.819       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.562      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 1.17        |
# |    value_loss           | 0.00054     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+03    |
# |    ep_rew_mean          | 2.01        |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 52          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.010070056 |
# |    clip_fraction        | 0.0931      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | 0.842       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.558      |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0159     |
# |    std                  | 1.18        |
# |    value_loss           | 0.000411    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+03    |
# |    ep_rew_mean          | 2.01        |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 53          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 54272       |
# | train/                  |             |
# |    approx_kl            | 0.011003077 |
# |    clip_fraction        | 0.0985      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | -0.0622     |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.537      |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0121     |
# ...
# |    value_loss           | 0.00147     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 978         |
# |    ep_rew_mean          | 4.28        |
# | time/                   |             |
# |    fps                  | 472         |
# |    iterations           | 473         |
# |    time_elapsed         | 1025        |
# |    total_timesteps      | 484352      |
# | train/                  |             |
# |    approx_kl            | 0.008327216 |
# |    clip_fraction        | 0.0462      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.1       |
# |    explained_variance   | 0.794       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.1        |
# |    n_updates            | 4720        |
# |    policy_gradient_loss | -0.00896    |
# |    std                  | 5.81        |
# |    value_loss           | 0.0206      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 978         |
# |    ep_rew_mean          | 4.29        |
# | time/                   |             |
# |    fps                  | 472         |
# |    iterations           | 474         |
# |    time_elapsed         | 1027        |
# |    total_timesteps      | 485376      |
# | train/                  |             |
# |    approx_kl            | 0.007816782 |
# |    clip_fraction        | 0.0487      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.1       |
# |    explained_variance   | 0.878       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.1        |
# |    n_updates            | 4730        |
# |    policy_gradient_loss | -0.0097     |
# |    std                  | 5.83        |
# |    value_loss           | 0.00982     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 978         |
# |    ep_rew_mean          | 4.29        |
# | time/                   |             |
# |    fps                  | 472         |
# |    iterations           | 475         |
# |    time_elapsed         | 1029        |
# |    total_timesteps      | 486400      |
# | train/                  |             |
# |    approx_kl            | 0.006568038 |
# |    clip_fraction        | 0.0333      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.1       |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.13       |
# |    n_updates            | 4740        |
# |    policy_gradient_loss | -0.0081     |
# |    std                  | 5.85        |
# |    value_loss           | 0.00293     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 955          |
# |    ep_rew_mean          | 4.54         |
# | time/                   |              |
# |    fps                  | 471          |
# |    iterations           | 476          |
# |    time_elapsed         | 1033         |
# |    total_timesteps      | 487424       |
# | train/                  |              |
# |    approx_kl            | 0.0047210655 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.1        |
# |    explained_variance   | 0.942        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -1.1         |
# |    n_updates            | 4750         |
# |    policy_gradient_loss | -0.00617     |
# |    std                  | 5.86         |
# |    value_loss           | 0.00202      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 931          |
# |    ep_rew_mean          | 4.68         |
# | time/                   |              |
# |    fps                  | 471          |
# |    iterations           | 477          |
# |    time_elapsed         | 1036         |
# |    total_timesteps      | 488448       |
# | train/                  |              |
# |    approx_kl            | 0.0011340425 |
# |    clip_fraction        | 0.000879     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.2        |
# |    explained_variance   | 0.349        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.891       |
# |    n_updates            | 4760         |
# |    policy_gradient_loss | -0.0019      |
# |    std                  | 5.88         |
# |    value_loss           | 0.651        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 931         |
# |    ep_rew_mean          | 4.7         |
# | time/                   |             |
# |    fps                  | 471         |
# |    iterations           | 478         |
# |    time_elapsed         | 1037        |
# |    total_timesteps      | 489472      |
# | train/                  |             |
# |    approx_kl            | 0.004297898 |
# |    clip_fraction        | 0.00879     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.608       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.09       |
# |    n_updates            | 4770        |
# |    policy_gradient_loss | -0.00702    |
# |    std                  | 5.89        |
# |    value_loss           | 0.0608      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 931          |
# |    ep_rew_mean          | 4.7          |
# | time/                   |              |
# |    fps                  | 471          |
# |    iterations           | 479          |
# |    time_elapsed         | 1039         |
# |    total_timesteps      | 490496       |
# | train/                  |              |
# |    approx_kl            | 0.0056009917 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.2        |
# |    explained_variance   | 0.563        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -1.11        |
# |    n_updates            | 4780         |
# |    policy_gradient_loss | -0.00872     |
# |    std                  | 5.92         |
# |    value_loss           | 0.00731      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 931         |
# |    ep_rew_mean          | 4.7         |
# | time/                   |             |
# |    fps                  | 471         |
# |    iterations           | 480         |
# |    time_elapsed         | 1042        |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.006436102 |
# |    clip_fraction        | 0.0326      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.699       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.14       |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | -0.00849    |
# |    std                  | 5.94        |
# |    value_loss           | 0.00304     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 942         |
# |    ep_rew_mean          | 4.6         |
# | time/                   |             |
# |    fps                  | 471         |
# |    iterations           | 481         |
# |    time_elapsed         | 1044        |
# |    total_timesteps      | 492544      |
# | train/                  |             |
# |    approx_kl            | 0.004031279 |
# |    clip_fraction        | 0.0107      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | 0.85        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.13       |
# |    n_updates            | 4800        |
# |    policy_gradient_loss | -0.00615    |
# |    std                  | 5.97        |
# |    value_loss           | 0.00108     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 954          |
# |    ep_rew_mean          | 4.53         |
# | time/                   |              |
# |    fps                  | 471          |
# |    iterations           | 482          |
# |    time_elapsed         | 1046         |
# |    total_timesteps      | 493568       |
# | train/                  |              |
# |    approx_kl            | 0.0016707245 |
# |    clip_fraction        | 0.00127      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.3        |
# |    explained_variance   | 0.676        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -1.09        |
# |    n_updates            | 4810         |
# |    policy_gradient_loss | -0.00285     |
# |    std                  | 5.99         |
# |    value_loss           | 0.0692       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 954          |
# |    ep_rew_mean          | 4.53         |
# | time/                   |              |
# |    fps                  | 471          |
# |    iterations           | 483          |
# |    time_elapsed         | 1049         |
# |    total_timesteps      | 494592       |
# | train/                  |              |
# |    approx_kl            | 0.0037662154 |
# |    clip_fraction        | 0.00576      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.3        |
# |    explained_variance   | 0.823        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -1.11        |
# |    n_updates            | 4820         |
# |    policy_gradient_loss | -0.00635     |
# |    std                  | 6.01         |
# |    value_loss           | 0.045        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 954          |
# |    ep_rew_mean          | 4.53         |
# | time/                   |              |
# |    fps                  | 471          |
# |    iterations           | 484          |
# |    time_elapsed         | 1051         |
# |    total_timesteps      | 495616       |
# | train/                  |              |
# |    approx_kl            | 0.0049309228 |
# |    clip_fraction        | 0.0118       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.3        |
# |    explained_variance   | 0.888        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -1.1         |
# |    n_updates            | 4830         |
# |    policy_gradient_loss | -0.00394     |
# |    std                  | 6.04         |
# |    value_loss           | 0.0139       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 954          |
# |    ep_rew_mean          | 4.53         |
# | time/                   |              |
# |    fps                  | 471          |
# |    iterations           | 485          |
# |    time_elapsed         | 1052         |
# |    total_timesteps      | 496640       |
# | train/                  |              |
# |    approx_kl            | 0.0059023486 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.4        |
# |    explained_variance   | 0.953        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -1.14        |
# |    n_updates            | 4840         |
# |    policy_gradient_loss | -0.00817     |
# |    std                  | 6.07         |
# |    value_loss           | 0.00208      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 954         |
# |    ep_rew_mean          | 4.48        |
# | time/                   |             |
# |    fps                  | 471         |
# |    iterations           | 486         |
# |    time_elapsed         | 1054        |
# |    total_timesteps      | 497664      |
# | train/                  |             |
# |    approx_kl            | 0.004004984 |
# |    clip_fraction        | 0.00605     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.4       |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.13       |
# |    n_updates            | 4850        |
# |    policy_gradient_loss | -0.00339    |
# |    std                  | 6.08        |
# |    value_loss           | 0.00157     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 954          |
# |    ep_rew_mean          | 4.48         |
# | time/                   |              |
# |    fps                  | 471          |
# |    iterations           | 487          |
# |    time_elapsed         | 1056         |
# |    total_timesteps      | 498688       |
# | train/                  |              |
# |    approx_kl            | 0.0064894976 |
# |    clip_fraction        | 0.0357       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.4        |
# |    explained_variance   | 0.84         |
# |    learning_rate        | 0.0001       |
# |    loss                 | -1.13        |
# |    n_updates            | 4860         |
# |    policy_gradient_loss | -0.00714     |
# |    std                  | 6.11         |
# |    value_loss           | 0.00497      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 954         |
# |    ep_rew_mean          | 4.23        |
# | time/                   |             |
# |    fps                  | 472         |
# |    iterations           | 488         |
# |    time_elapsed         | 1058        |
# |    total_timesteps      | 499712      |
# | train/                  |             |
# |    approx_kl            | 0.002299388 |
# |    clip_fraction        | 0.00322     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.5       |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -1.13       |
# |    n_updates            | 4870        |
# |    policy_gradient_loss | -0.00336    |
# |    std                  | 6.15        |
# |    value_loss           | 0.00157     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 954          |
# |    ep_rew_mean          | 4.23         |
# | time/                   |              |
# |    fps                  | 472          |
# |    iterations           | 489          |
# |    time_elapsed         | 1059         |
# |    total_timesteps      | 500736       |
# | train/                  |              |
# |    approx_kl            | 0.0028443309 |
# |    clip_fraction        | 0.00703      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.5        |
# |    explained_variance   | 0.946        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -1.14        |
# |    n_updates            | 4880         |
# |    policy_gradient_loss | -0.00415     |
# |    std                  | 6.19         |
# |    value_loss           | 0.0022       |
# ------------------------------------------

# %%
from stable_baselines3 import PPO

model = PPO.load("ppo_robot_cup_no_norm", device="cpu")
env   = RobotCupEnv(render_mode="human")

obs, _       = env.reset()
total_reward = 0.0

for _ in range(500):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, trunc, _ = env.step(action)
    total_reward += reward
    if done or trunc:
        break

# Tilt final
pos, quat = p.getBasePositionAndOrientation(env.cup_id, physicsClientId=env.client)
roll, pitch, _ = p.getEulerFromQuaternion(quat)
env.close()

print(f"🎯 Recompensa acumulada: {total_reward:.3f}")
print(f"🔄 Tilt final → roll: {roll:.2f} rad, pitch: {pitch:.2f} rad")
# Out:
# 🎯 Recompensa acumulada: 6.150
# 🔄 Tilt final → roll: -0.84 rad, pitch: 0.11 rad

# %%
import numpy as np
from stable_baselines3 import PPO

# 1) (Re)crea el env HUMAN para evaluación
env   = RobotCupEnv(render_mode="human")
model = PPO.load("ppo_robot_cup_no_norm", device="cpu")

n_eval = 20
rewards, lengths, tilts = [], [], []

for _ in range(n_eval):
    obs, _     = env.reset()
    total_r, t = 0.0, 0
    while True:
        action, _ = model.predict(obs, deterministic=True)
        obs, r, done, trunc, _ = env.step(action)
        total_r += r
        t       += 1
        if done or trunc:
            break
    # tilt final
    _, quat = p.getBasePositionAndOrientation(env.cup_id, physicsClientId=env.client)
    roll, _, _ = p.getEulerFromQuaternion(quat)

    rewards.append(total_r)
    lengths.append(t)
    tilts.append(abs(roll))

env.close()

print(f"Rew mean/std: {np.mean(rewards):.2f} ± {np.std(rewards):.2f}")
print(f"Steps mean/std: {np.mean(lengths):.1f} ± {np.std(lengths):.1f}")
print(f"Tilt mean/std: {np.mean(tilts):.2f} rad ± {np.std(tilts):.2f}")
# Out:
# Rew mean/std: 1.39 ± 4.36
# Steps mean/std: 847.8 ± 538.1
# Tilt mean/std: 0.17 rad ± 0.33
